# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
players = pd.read_csv('data/player stats.csv')
players['Player'] = players['Player'].ffill()
players['Thrown Up'] = players['Thrown Up'].fillna(0)
players.head(3)
# Out:
#             Player  Season  Games  Goals  Assists  Clean Sheets  Thrown Up
# 0  Rishabh Kaushal       1    4.0      1        1           NaN        0.0
# 1  Rishabh Kaushal       2    6.0      2        0           NaN        0.0
# 2  Rishabh Kaushal       3    7.0      2        1           NaN        0.0

# %%
positions = pd.read_csv('data/positions.csv')
players_merged = players.merge(positions, left_on='Player', right_on='Players')
players_merged = players_merged.drop(columns=['Players'])
players_merged
# Out:
#                 Player  Season  Games  Goals  Assists  Clean Sheets  \
# 0      Rishabh Kaushal       1    4.0      1        1           NaN
# 1      Rishabh Kaushal       2    6.0      2        0           NaN
# 2      Rishabh Kaushal       3    7.0      2        1           NaN
# 3      Rishabh Kaushal       4    3.0      2        0           NaN
# 4            Edward Lu       1    4.0      1        0           NaN
# ..                 ...     ...    ...    ...      ...           ...
# 69      Allen Vadukoot       4    3.0      2        0           NaN
# 70  John-Henry Pezzuto       3    3.0      0        0           1.0
# 71          Aiden Hall       2    2.0      0        0           NaN
# 72            Jeff Lai       2    1.0      0        0           NaN
# 73            Max Irby       3    2.0      0        1           NaN
#
#     Thrown Up        Role                     Position
# 0         0.0    Attacker                      Striker
# 1         0.0    Attacker                      Striker
# 2         0.0    Attacker                      Striker
# 3         0.0    Attacker                      Striker
# 4         0.0    Defender                   Centerback
# ..        ...         ...                          ...
# 69        0.0    Attacker                      Striker
# 70        0.0  Goalkeeper                   Goalkeeper
# 71        0.0  Midfielder           Central Midfielder
# 72        0.0        Jeff                         Jeff
# 73        0.0  Midfielder  Center Attacking Midfielder
#
# [74 rows x 9 columns]

# %%
players_merged.to_csv('data, player stats.csv', index=False)

# %%
all_time = players_merged[['Player', 'Games', 'Goals', 'Assists','Clean Sheets','Thrown Up', 'Role', 'Position']].groupby('Player').agg({'Games':'sum', 'Goals':'sum','Assists':'sum','Clean Sheets':'sum', 'Thrown Up':'sum', 'Role':'max', 'Position':'max'})
all_time
# Out:
#                               Games  Goals  Assists  Clean Sheets  Thrown Up  \
# Player
# Adi Gupta                       1.0     -1        0           0.0        0.0
# Agasthya Valluri                4.0      0        0           0.0        1.0
# Aiden Hall                      2.0      0        0           0.0        0.0
# Alec Balandin                   3.0      0        0           0.0        0.0
# Alessandro Tanghwa              4.0      0        0           0.0        0.0
# Allen Keissieh                 13.0      0        0           0.0        0.0
# Allen Vadukoot                  3.0      2        0           0.0        0.0
# Allen Yan                      19.0      0        0           5.0        0.0
# Andres Caliz                    5.0      0        1           0.0        0.0
# Andrew Cen                      8.0      1        2           0.0        0.0
# Andrew Trieu                    1.0      0        0           0.0        0.0
# Arturo                          2.0      1        0           0.0        0.0
# Axel Yarahuaman                 8.0      0        0           0.0        0.0
# Brayan Loza                     1.0      0        0           0.0        0.0
# Cesar                           1.0      2        1           0.0        0.0
# Daniel Berreondo-Cendejas      22.0      1        0           0.0        0.0
# Decheng Liu                     3.0      0        0           0.0        0.0
# Derrick Chen                    4.0      0        0           0.0        0.0
# Edward Lu                      22.0      1        0           0.0        0.0
# Eric Gu                        24.0      0        0           0.0        0.0
# Gage Rullhausen                 5.0      2        1           0.0        0.0
# George Petkov                   2.0      0        1           0.0        0.0
# Ha Son                          2.0      0        0           0.0        0.0
# Harshil Dodiya                  5.0      0        1           0.0        0.0
# Jaydon G.                       1.0      0        0           0.0        0.0
# Jeff Lai                        1.0      0        0           0.0        0.0
# Jeffrey Phillips                5.0      3        2           0.0        0.0
# John-Henry Pezzuto              3.0      0        0           1.0        0.0
# Jose                            1.0      2        1           0.0        0.0
# Justin Duy                      4.0      0        0           0.0        0.0
# Leo Luca                        2.0      0        0           0.0        0.0
# Mark Ruangrattham              24.0      2        5           0.0        0.0
# Matt                            3.0      0        1           0.0        0.0
# Max Irby                        2.0      0        1           0.0        0.0
# Mohammed Khamsya bin Khidzer    8.0      1        0           0.0        0.0
# Nathan Vechoor                  6.0      4        3           0.0        0.0
# Nick Capezzone                  1.0      0        0           0.0        0.0
# Nicolas Colebank               25.0      0        1           0.0        0.0
# Pato Harris                     6.1      5        0           0.0        0.0
# Pedro Serdio                    1.0      0        0           0.0        0.0
# Rishabh Kaushal                20.0      7        2           0.0        0.0
# Robbie Sandborn                 8.0      2        2           0.0        0.0
# Shon John                       4.0      0        0           0.0        1.0
# Shrey Kumar                     1.0      0        0           0.0        0.0
# Tomas Tabaoda                   8.0      2        2           0.0        0.0
# Vivin Vinil                     2.0      0        0           0.0        0.0
#
#                                     Role                     Position
# Player
# Adi Gupta                       Attacker                  Left Winger
# Agasthya Valluri              Midfielder           Central Midfielder
# Aiden Hall                    Midfielder           Central Midfielder
# Alec Balandin                   Attacker                      Striker
# Alessandro Tanghwa              Defender                   Centerback
# Allen Keissieh                Midfielder           Central Midfielder
# Allen Vadukoot                  Attacker                      Striker
# Allen Yan                     Goalkeeper                   Goalkeeper
# Andres Caliz                  Midfielder  Center Attacking Midfielder
# Andrew Cen                      Attacker                  Left Winger
# Andrew Trieu                    Defender                   Centerback
# Arturo                          Attacker                      Striker
# Axel Yarahuaman                 Defender                   Centerback
# Brayan Loza                     Defender                   Centerback
# Cesar                           Attacker                      Striker
# Daniel Berreondo-Cendejas       Defender                    Left Back
# Decheng Liu                     Attacker                  Left Winger
# Derrick Chen                  Midfielder           Central Midfielder
# Edward Lu                       Defender                   Centerback
# Eric Gu                         Defender                   Centerback
# Gage Rullhausen               Midfielder             Right Midfielder
# George Petkov                 Midfielder             Right Midfielder
# Ha Son                          Defender                    Left Back
# Harshil Dodiya                Midfielder  Center Attacking Midfielder
# Jaydon G.                       Defender                   Centerback
# Jeff Lai                            Jeff                         Jeff
# Jeffrey Phillips              Midfielder             Right Midfielder
# John-Henry Pezzuto            Goalkeeper                   Goalkeeper
# Jose                            Attacker                      Striker
# Justin Duy                    Goalkeeper                   Goalkeeper
# Leo Luca                        Attacker                 Right Winger
# Mark Ruangrattham             Midfielder  Center Defensive Midfielder
# Matt                            Attacker                 Right Winger
# Max Irby                      Midfielder  Center Attacking Midfielder
# Mohammed Khamsya bin Khidzer    Defender                   Centerback
# Nathan Vechoor                  Attacker                 Right Winger
# Nick Capezzone                  Attacker                 Right Winger
# Nicolas Colebank                Defender                   Centerback
# Pato Harris                     Attacker                      Striker
# Pedro Serdio                    Defender                   Right Back
# Rishabh Kaushal                 Attacker                      Striker
# Robbie Sandborn                 Defender                   Centerback
# Shon John                       Defender                   Right Back
# Shrey Kumar                   Midfielder  Center Defensive Midfielder
# Tomas Tabaoda                   Attacker                 Right Winger
# Vivin Vinil                   Midfielder           Central Midfielder

# %%
len(players['Player'].unique())
# Out:
# 46

# %%
# X-Axis Assists, Y-Axis Goals, Color Role, Label Player

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Franklin Gothic Medium'

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Data for plotting
x = all_time['Assists']
y = all_time['Goals']

# Plot the heart rate and shaded area
ax.scatter(x, y, color='crimson', label='Average Heart Rate',
        marker='o', markeredgewidth=4, markeredgecolor='crimson', markerfacecolor='crimson')

# Hide spines
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['top'].set_visible(False)

# Customize tick parameters
ax.tick_params(axis='x', which='major', direction='out', length=10, width=1,
               color='black', pad=15, labelsize=8, labelcolor='gray', labelrotation=0)

# Background colors
ax.set_facecolor("white")  # Plot background
fig.set_facecolor("white")  # Figure background

# Labels and layout
ax.set_xlabel('Time (Hour of Day)')
ax.set_ylabel('Heart Rate (bpm)')

# Customizing the legend
legend = ax.legend(loc='upper left', title='Legend', bbox_to_anchor=(1, 1), frameon=False)
plt.setp(legend.get_texts(), color='gray', fontproperties=franklin_ita)  # Gray color and no bold
plt.setp(legend.get_title(), color='black', fontproperties=franklin_ita)  # Gray legend title

# Grid
ax.grid(True, which='major', color='gray', linestyle='--', linewidth=0.5)

plt.xticks(rotation=0)
plt.tight_layout()
plt.ylim(0, 100)

plt.savefig("heart_rate_plot.png", format="png", dpi=300, bbox_inches="tight")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 9
#       6 fig, ax = plt.subplots(figsize=(12, 6))
#       8 # Data for plotting
# ----> 9 x = hrh_average.index
#      10 y = hrh_average['hr']
#      12 # Plot the heart rate and shaded area
#
# NameError: name 'hrh_average' is not defined
